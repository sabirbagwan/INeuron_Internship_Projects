# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df_ALLCountries_Data = pd.read_csv('./IDS_CSV/IDS_ALLCountries_Data.csv')
df_ALLCountries_Data
# Out:
#                                             Country Name Country Code  \
# 0                                            Afghanistan          AFG
# 1                                            Afghanistan          AFG
# 2                                            Afghanistan          AFG
# 3                                            Afghanistan          AFG
# 4                                            Afghanistan          AFG
# ...                                                  ...          ...
# 77384                                                NaN          NaN
# 77385                                                NaN          NaN
# 77386                                                NaN          NaN
# 77387  Data from database: International Debt Statistics          NaN
# 77388                           Last Updated: 10/10/2021          NaN
#
#       Counterpart-Area Name Counterpart-Area Code  \
# 0                     World                   WLD
# ...

# %%
df_ALLCountries_Data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Counterpart-Area Name',
#        'Counterpart-Area Code', 'Series Name', 'Series Code', '1970', '1971',
#        '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980',
#        '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025',
#        '2026', '2027', '2028'],
#       dtype='object')

# %%
df_ALLCountries_Data.shape
# Out:
# (77389, 65)

# %% [markdown]
# ### Finding the number of distinct countries

# %%
# item_counts = df["Your_Column"].value_counts()
number = df_ALLCountries_Data['Country Name'].value_counts()
number
# Out:
# Afghanistan                                          569
# Panama                                               569
# Nepal                                                569
# Nicaragua                                            569
# Niger                                                569
#                                                     ...
# Grenada                                              569
# Guatemala                                            569
# Guinea                                               569
# Data from database: International Debt Statistics      1
# Last Updated: 10/10/2021                               1
# Name: Country Name, Length: 138, dtype: int64

# %% [markdown]
# ### The number of distinct countries are 138 as given by the length

# %% [markdown]
# ### Below we will find the names of the countries

# %%
df_ALLCountries_Data['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Azerbaijan', 'Bangladesh', 'Belarus', 'Belize',
#        'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde',
#        'Cambodia', 'Cameroon', 'Central African Republic', 'Chad',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Djibouti', 'Dominica',
#        'Dominican Republic',
#        'East Asia & Pacific (excluding high income)', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Eritrea', 'Eswatini',
#        'Ethiopia', 'Europe & Central Asia (excluding high income)',
#        'Fiji', 'Gabon', 'Gambia, The', 'Georgia', 'Ghana', 'Grenada',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Honduras', 'IDA only', 'India', 'Indonesia', 'Iran, Islamic Rep.',
# ...

# %%
df_CountryMetaData = pd.read_csv('./IDS_CSV/IDS_CountryMetaData.csv', encoding='unicode_escape')
df_CountryMetaData.head()
# Out:
#   Code                                Long Name         Income Group  \
# 0  AFG             Islamic State of Afghanistan           Low income
# 1  ALB                      Republic of Albania  Upper middle income
# 2  DZA  People's Democratic Republic of Algeria  Lower middle income
# 3  AGO              People's Republic of Angola  Lower middle income
# 4  ARG                       Argentine Republic  Upper middle income
#
#                        Region Lending category Other groups   Currency Unit  \
# 0                  South Asia              IDA         HIPC  Afghan afghani
# 1       Europe & Central Asia             IBRD          NaN    Albanian lek
# 2  Middle East & North Africa             IBRD          NaN  Algerian dinar
# 3          Sub-Saharan Africa             IBRD          NaN  Angolan kwanza
# 4   Latin America & Caribbean             IBRD          NaN  Argentine peso
#
#   Latest population census                     Latest household survey  \
# ...

# %%
df_CountryMetaData.columns
# Out:
# Index(['Code', 'Long Name', 'Income Group', 'Region', 'Lending category',
#        'Other groups', 'Currency Unit', 'Latest population census',
#        'Latest household survey', 'Special Notes',
#        'National accounts base year', 'National accounts reference year',
#        'System of National Accounts', 'SNA price valuation',
#        'Alternative conversion factor', 'PPP survey years',
#        'Balance of Payments Manual in use', 'External debt Reporting status',
#        'System of trade', 'Government Accounting concept',
#        'IMF data dissemination standard',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', '2-alpha code', 'WB-2 code',
#        'Table Name', 'Short Name'],
#       dtype='object')

# %%
df_Country_SeriesMetaData = pd.read_csv('./IDS_CSV/IDS_Country-SeriesMetaData.csv', encoding='unicode_escape')
df_Country_SeriesMetaData.head()
# Out:
#              Type       Country Code  \
# 0  Country-Series  Afghanistan (AFG)
# 1  Country-Series  Afghanistan (AFG)
# 2  Country-Series       Angola (AGO)
# 3  Country-Series       Angola (AGO)
# 4  Country-Series      Albania (ALB)
#
#                                          Series Code  \
# 0  Foreign direct investment, net inflows in repo...
# 1  External debt stocks, total (DOD, current US$)...
# 2  Foreign direct investment, net inflows in repo...
# 3  External debt stocks, total (DOD, current US$)...
# 4  Foreign direct investment, net inflows in repo...
#
#                                          Description
# 0  Data on Foreign Direct Investment are based on...
# 1  Long-term public and publicly guaranteed and l...
# 2  Data on Foreign Direct Investment are based on...
# 3  Long-term public and publicly guaranteed debt ...
# 4  Data on Foreign Direct Investment are based on...

# %%
df_Country_SeriesMetaData.columns
# Out:
# Index(['Type', 'Country Code', 'Series Code', 'Description'], dtype='object')

# %%
df_Footnotes = pd.read_csv('./IDS_CSV/IDS_Footnotes.csv', encoding='unicode_escape')
df_Footnotes.head()
# Out:
#        Type       Country Code  \
# 0  FootNote  Afghanistan (AFG)
# 1  FootNote  Afghanistan (AFG)
# 2  FootNote  Afghanistan (AFG)
# 3  FootNote  Afghanistan (AFG)
# 4  FootNote  Afghanistan (AFG)
#
#                                          Series Code      Time Code  \
# 0  Foreign direct investment, net inflows in repo...  1970 (YR1970)
# 1  Foreign direct investment, net inflows in repo...  1971 (YR1971)
# 2  Foreign direct investment, net inflows in repo...  1972 (YR1972)
# 3  Foreign direct investment, net inflows in repo...  1973 (YR1973)
# 4  Foreign direct investment, net inflows in repo...  1976 (YR1976)
#
#                                          Description
# 0  Source: United Nations Conference on Trade and...
# 1  Source: United Nations Conference on Trade and...
# 2  Source: United Nations Conference on Trade and...
# 3  Source: United Nations Conference on Trade and...
# 4  Source: United Nations Conference on Trade and...

# %%
df_Footnotes.columns
# Out:
# Index(['Type', 'Country Code', 'Series Code', 'Time Code', 'Description'], dtype='object')

# %%
df_SeriesMetaData = pd.read_csv('./IDS_CSV/IDS_SeriesMetaData.csv', encoding='unicode_escape')
df_SeriesMetaData.head()
# Out:
#           Code License Type  \
# 0  DT.GPA.DPPG          NaN
# 1  DT.GPA.OFFT          NaN
# 2  DT.GPA.PRVT          NaN
# 3  DT.GRE.DPPG          NaN
# 4  DT.GRE.OFFT          NaN
#
#                                       Indicator Name  \
# 0  Average grace period on new external debt comm...
# 1  Average grace period on new external debt comm...
# 2  Average grace period on new external debt comm...
# 3  Average grant element on new external debt com...
# 4  Average grant element on new external debt com...
#
#                                     Short definition  \
# 0  Grace period is the period from the date of si...
# 1  Grace period is the period from the date of si...
# 2  Grace period is the period from the date of si...
# 3  The grant element of a loan is the grant equiv...
# 4  The grant element of a loan is the grant equiv...
#
#                                      Long definition  \
# 0  Grace period is the period from the date of si...
# ...

# %%
df_SeriesMetaData.columns
# Out:
# Index(['Code', 'License Type', 'Indicator Name', 'Short definition',
#        'Long definition', 'Source', 'Topic', 'Dataset', 'Periodicity',
#        'Aggregation method', 'General comments'],
#       dtype='object')

# %% [markdown]
# ### Below is finding out the distinct Indicator Names

# %%
df_SeriesMetaData['Indicator Name'].unique()
# Out:
# array(['Average grace period on new external debt commitments (years)',
#        'Average grace period on new external debt commitments, official (years)',
#        'Average grace period on new external debt commitments, private (years)',
#        'Average grant element on new external debt commitments (%)',
#        'Average grant element on new external debt commitments, official (%)',
#        'Average grant element on new external debt commitments, private (%)',
#        'Average interest on new external debt commitments (%)',
#        'Average interest on new external debt commitments, official (%)',
#        'Average interest on new external debt commitments, private (%)',
#        'Average maturity on new external debt commitments (years)',
#        'Average maturity on new external debt commitments, official (years)',
#        'Average maturity on new external debt commitments, private (years)',
#        'CB, bilateral (AMT, current US$)',
# ...

# %% [markdown]
# ### Finding out number of distinct Indicators

# %%
NumberOfIndicators = df_SeriesMetaData['Indicator Name'].value_counts()
NumberOfIndicators
# Out:
# Average grace period on new external debt commitments (years)    1
# PPG, multilateral concessional (DOD, current US$)                1
# PPG, multilateral (DIS, current US$)                             1
# PPG, multilateral (DOD, current US$)                             1
# PPG, multilateral (INT, current US$)                             1
#                                                                 ..
# GG, official creditors (TDS, current US$)                        1
# GG, official creditors (NTR, current US$)                        1
# GG, official creditors (NFL, current US$)                        1
# GG, official creditors (INT, current US$)                        1
# Use of IMF credit, SDR allocations (DOD, current US$)            1
# Name: Indicator Name, Length: 562, dtype: int64

# %% [markdown]
# ### We see the number of distinct indicators are 562

# %% [markdown]
# ### Finding out the most common Debt Indicator

# %%
df_SeriesMetaData['Indicator Name'].value_counts().idxmax()
# Out:
# 'Average grace period on new external debt commitments (years)'

# %% [markdown]
# ### We see the most common Debt Indicator is 'Average grace period on new external debt commitments (years)'

# %%
df_Series_TimeMetaData = pd.read_csv('./IDS_CSV/IDS_Series-TimeMetaData.csv', encoding='unicode_escape')
df_Series_TimeMetaData.head()
# Out:
#           Type                                        Series Code  Time Code  \
# 0  Series-Time  Present value of external debt (current US$) (...   (YR2020)
# 1  Series-Time  Present value of external debt (% of exports o...   (YR2020)
# 2  Series-Time  Present value of external debt (% of GNI) (DT....   (YR2020)
#
#                                          Description
# 0  Present value calculations for these countries...
# 1  Present value calculations for these countries...
# 2  Present value calculations for these countries...

# %%
df_Series_TimeMetaData.columns
# Out:
# Index(['Type', 'Series Code', 'Time Code', 'Description'], dtype='object')
